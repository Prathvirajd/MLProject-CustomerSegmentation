# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv('CC GENERAL.csv')

# %%
dataset.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
dataset.shape
# Out:
# (8950, 18)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
dataset.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
dataset['MINIMUM_PAYMENTS'] = dataset['MINIMUM_PAYMENTS'].fillna(dataset['MINIMUM_PAYMENTS'].mean())
dataset['CREDIT_LIMIT'] = dataset['CREDIT_LIMIT'].fillna(dataset['CREDIT_LIMIT'].mean())

# %%
dataset.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.drop(columns=['CUST_ID'],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
dataset.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
plt.figure(figsize=(20,35))
for i, col in enumerate(dataset.columns):
    if dataset[col].dtype != 'object':
        ax = plt.subplot(9, 2, i+1)
        sns.kdeplot(dataset[col], ax=ax)
        plt.xlabel(col)
        
plt.show()

# %%
plt.figure(figsize=(15,65))
for i in range(0,17):
    plt.subplot(17,1,i+1)
    sns.distplot(dataset[dataset.columns[i]],kde_kws={'color':'r','bw': 0.1,'lw':3,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(dataset.columns[i])
plt.tight_layout()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(dataset.corr(), annot=True)
plt.show()

# %% [markdown]
# # Data scaling

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
scaled_data = scalar.fit_transform(dataset)

# %% [markdown]
# # Dimensionality reduction - PCA

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import metrics

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)
pca_data = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_data
# Out:
#           PCA1      PCA2
# 0    -1.682221 -1.076447
# 1    -1.138300  2.506475
# 2     0.969683 -0.383529
# 3    -0.873630  0.043169
# 4    -1.599434 -0.688577
# ...        ...       ...
# 8945 -0.359628 -2.016140
# 8946 -0.564367 -1.639113
# 8947 -0.926203 -1.810779
# 8948 -2.336549 -0.657959
# 8949 -0.556419 -0.400476
#
# [8950 rows x 2 columns]

# %% [markdown]
# # Determining 'k' value by elbow method

# %%
inertia = []
range_val = range(1,15)
for i in range_val:
    kmean = KMeans(n_clusters=i)
    kmean.fit_predict(pd.DataFrame(scaled_data))
    inertia.append(kmean.inertia_)
plt.plot(range_val,inertia,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %% [markdown]
# # Model building

# %%
kmeans_model=KMeans(4)
kmeans_model.fit_predict(scaled_data)
pca_data_kmeans= pd.concat([pca_data,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %% [markdown]
# # Visualizing clusters

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_data_kmeans,palette=['blue','red','green','black'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[dataset.columns])

# %%
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[dataset.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  4602.462714          0.968415   501.896219       320.373681
# 1   894.768927          0.934715  1236.263333       593.995933
# 2  1011.839396          0.789924   270.144981       209.932625
# 3  3551.153761          0.986879  7681.620098      5095.878826
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             181.607404  4520.724309            0.287731
# 1             642.541696   209.816318            0.885255
# 2              60.479311   596.300906            0.170250
# 3            2587.208264   653.638891            0.946418
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.138934                         0.185516
# 1                   0.297109                         0.711930
# 2                   0.086301                         0.080662
# 3                   0.739031                         0.788060
#
# ...

# %% [markdown]
# # Create new column for clusters

# %%
cluster_data = pd.concat([dataset,pd.DataFrame({'Cluster':kmeans_model.labels_})],axis=1)
cluster_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1_data = cluster_data[cluster_data["Cluster"]==0]
cluster_1_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    6886.213231           1.000000    1611.70              0.00
# 23    3800.151377           0.818182    4248.35           3454.56
# 24    5368.571219           1.000000       0.00              0.00
# 28    7152.864372           1.000000     387.05            204.55
# ...           ...                ...        ...               ...
# 8857  2330.222764           1.000000    1320.00              0.00
# 8858   812.934042           1.000000      50.00             50.00
# 8869  2171.222526           1.000000     791.18            791.18
# 8915   381.341657           1.000000      78.00              0.00
# 8941  5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# ...

# %%
cluster_2_data = cluster_data[cluster_data["Cluster"]==1]
cluster_2_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000     773.17            773.17
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 10    1293.124939           1.000000     920.12              0.00
# 12    1516.928620           1.000000    3217.99           2500.23
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                       0.00           0.0             1.000000
# ...

# %%
cluster_3_data = cluster_data[cluster_data["Cluster"]==2]
cluster_3_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 8     1014.926473           1.000000     861.49            661.49
# 9      152.225975           0.545455    1281.60           1281.60
# ...           ...                ...        ...               ...
# 8939   728.352548           1.000000     734.40            734.40
# 8943     5.871712           0.500000      20.90             20.90
# 8944   193.571722           0.833333    1012.73           1012.73
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       95.4      0.000000             0.166667
# ...

# %%
cluster_4_data = cluster_data[cluster_data["Cluster"] == 3]
cluster_4_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      627.260806           1.000000    7091.01           6402.63
# 21    6369.531318           1.000000    6359.95           5910.04
# 57    2386.330629           1.000000    5217.62           4789.09
# 84    1935.362486           1.000000    4915.60           4515.34
# 90    9381.255094           1.000000    5100.07           1147.83
# ...           ...                ...        ...               ...
# 8215  4436.557694           1.000000    6005.90           5838.38
# 8541  3326.323283           1.000000    8209.77           2218.28
# 8662   599.909949           1.000000    4947.32           3149.59
# 8689   368.318662           0.909091    8053.95           8053.95
# 8737  2533.618119           0.909091    5633.83           2985.92
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# ...

# %%
sns.countplot(x='Cluster', data=cluster_data)
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='count'>

# %%
for c in cluster_data.drop(['Cluster'],axis=1):
    grid= sns.FacetGrid(cluster_data, col='Cluster')
    grid= grid.map(plt.hist, c)
plt.show()

# %% [markdown]
# # Saving kmeans model and cluster labels

# %%
import joblib
joblib.dump(kmeans_model, "kmeans_model.pkl")
# Out:
# ['kmeans_model.pkl']

# %%
cluster_data.to_csv("cluster_data.csv")

# %% [markdown]
# # Training and testing the model using decision tree

# %%
X = cluster_data.drop(['Cluster'],axis=1)
y= cluster_data[['Cluster']]
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5322    19.962737           1.000000     287.40              0.00
# 135   1562.633343           1.000000    1330.62           1169.63
# 344    260.838885           1.000000    2854.11           1797.96
# 7799   357.593551           1.000000      68.00              0.00
# 6892     8.768020           0.500000       0.00              0.00
# ...           ...                ...        ...               ...
# 5775  1826.387864           1.000000       0.00              0.00
# 6460    68.007411           1.000000     488.66              0.00
# 7002    45.663290           0.454545      77.00             77.00
# 3462  1034.253025           1.000000     144.00              0.00
# 8451  2373.308268           1.000000       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5322                  287.40      0.000000             1.000000
# ...

# %%
X_test
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 4700  4070.500764           0.833333     710.80            140.00
# 2121  1189.665497           0.909091       0.00              0.00
# 7291  3610.883496           1.000000       0.00              0.00
# 2212  9226.107838           1.000000    2217.94            990.46
# 2176     5.016768           0.909091     284.13              0.00
# ...           ...                ...        ...               ...
# 386   1526.506915           1.000000      46.67             46.67
# 8159   135.357366           0.818182    1592.57           1132.05
# 3561  1077.019958           1.000000     465.90            398.10
# 5851  1111.811966           1.000000       0.00              0.00
# 1705  2431.193194           1.000000       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 4700                  570.80   4620.069456             0.833333
# ...

# %%
model= DecisionTreeClassifier(criterion="entropy")
model.fit(X_train, y_train)
y_predict = model.predict(X_test)

# %%
print(metrics.confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[ 339   14   30    4]
#  [  18  984   39   10]
#  [  26   28 1073    2]
#  [   1    9    1  107]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       387
#            1       0.95      0.94      0.94      1051
#            2       0.94      0.95      0.94      1129
#            3       0.87      0.91      0.89       118
#
#     accuracy                           0.93      2685
#    macro avg       0.91      0.92      0.91      2685
# weighted avg       0.93      0.93      0.93      2685

# %% [markdown]
# # Save the DT model for new predictions

# %%
import pickle
filename = 'final_model.sav'
pickle.dump(model, open(filename, 'wb'))
 
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result,'% Acuuracy')
# Out:
# 0.9322160148975791 % Acuuracy
